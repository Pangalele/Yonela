# %%
import pandas as pd
	
#load dataframe from csv
df = pd.read_csv("Product3.csv")

#print dataframe
df
# Out:
#    Product type                           Product Name  Products Qty  \
# 0         Chips                                    NaN           NaN
# 1           NaN                                Cheetos           5.0
# 2           NaN                     Cool Ranch Doritos          10.0
# 3           NaN                           Fritos Corn           15.0
# 4           NaN                                Funyuns          20.0
# 5           NaN                  Lays BBQ Potato Chips          10.0
# 6    Cooldrinks                                    NaN           NaN
# 7           NaN               Coca-Cola Orange Vanilla          12.0
# 8           NaN                         Diet Coke Lime          12.0
# 9           NaN                         Diet coke Plus          12.0
# 10          NaN                                  Fanta          12.0
# 11          NaN                               Delaware          12.0
# 12         Pies                                    NaN           NaN
# ...

# %%
import pandas as pd

# using header argument
df = pd.read_csv('Product3.csv', header=None)

df
# Out:
#                0                                      1             2  \
# 0   Product type                           Product Name  Products Qty
# 1          Chips                                    NaN           NaN
# 2            NaN                                Cheetos             5
# 3            NaN                     Cool Ranch Doritos            10
# 4            NaN                           Fritos Corn             15
# 5            NaN                                Funyuns            20
# 6            NaN                  Lays BBQ Potato Chips            10
# 7     Cooldrinks                                    NaN           NaN
# 8            NaN               Coca-Cola Orange Vanilla            12
# 9            NaN                         Diet Coke Lime            12
# 10           NaN                         Diet coke Plus            12
# 11           NaN                                  Fanta            12
# ...
